# %%
import pandas as pd
import numpy as np

# %%
df_estudiante=pd.read_csv('/content/drive/MyDrive/StudentsPerformance (1).csv')
df_estudiante
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Operaciones en columnas,lo primero que debemos hacer es elegir la columna que quiero, ojala una columna numerica
df_estudiante['reading score']
# Out:
# 0      72
# 1      90
# 2      95
# 3      57
# 4      78
#        ..
# 995    99
# 996    55
# 997    71
# 998    78
# 999    86
# Name: reading score, Length: 1000, dtype: int64

# %%
#Sumar datos de una columna
df_estudiante['reading score'].sum()
# Out:
# 69169

# %%
#Como contar datos de una columna
df_estudiante['reading score'].count()
# Out:
# 1000

# %%
#Calcular el promedio de uuna columna, se usa el método mean
df_estudiante['reading score'].mean()
# Out:
# 69.169

# %%
#Para calcular la desviacion de una columna uso el método std
df_estudiante['reading score'].std()
# Out:
# 14.60019193725222

# %%
#Para ver lo valores máximos de una columa usamos el método, max.
df_estudiante['reading score'].max()
# Out:
# 100

# %%
#Para ver le valor minimo de una columna usamos el método, min}
df_estudiante['reading score'].min()
# Out:
# 17

# %%
#Para ver las medidas de tendencia central de una columna usamos el método describe.
df_estudiante['reading score'].describe()
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
df_estudiante
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#Operaciones entre filas, empecemos con la suma
df_estudiante['math score']+df_estudiante['writing score']+df_estudiante['reading score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
#Así guardo una columna calculada
df_estudiante['Total']=df_estudiante['math score']+df_estudiante['writing score']+df_estudiante['reading score']
df_estudiante
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total
# ...

# %%
#Calcula el promedio de las notas que hay.
(df_estudiante['Total'])/3
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: Total, Length: 1000, dtype: float64

# %%
#Guardamos el resultado en una nueva columna.
df_estudiante['Promedio']=(df_estudiante['Total'])/3
df_estudiante
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Así formateo los numeros para que tengan solo dos decimales.
df_estudiante.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Contamos elementos por valor con el método len
len(df_estudiante['gender'])
# Out:
# 1000

# %%
#Para contar cada uno uso el método values.counts
df_estudiante['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
#Para contar la raza y grupos etnicos en este caso
df_estudiante['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
#Agrupamos por parental level of education
df_estudiante['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
#Calcular el valor de participación por cada elemento
df_estudiante['race/ethnicity'].value_counts(normalize=True)*100
# Out:
# race/ethnicity
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: proportion, dtype: float64

# %%
#Podemos organizar los dataframe no solo ppor una columna si no por dos
df_estudiante.sort_values(['reading score', 'writing score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 458  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
organizado_escritura=df_estudiante.sort_values(['reading score', 'writing score'], ascending=False)
organizado_escritura.to_csv('organizado_escritura.csv', index=False)

# %%
#De esta manera guardo los datos y sobreescribir sin reusar la variable.
df_estudiante.sort_values(['reading score', 'writing score'], ascending=False,
                          inplace=True)

# %%
df_estudiante
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 106  female        group D             master's degree      standard
# 114  female        group E           bachelor's degree      standard
# 165  female        group C           bachelor's degree      standard
# 179  female        group D            some high school      standard
# 458  female        group E           bachelor's degree      standard
# ..      ...            ...                         ...           ...
# 76     male        group E            some high school      standard
# 980  female        group B                 high school  free/reduced
# 596    male        group B                 high school  free/reduced
# 327    male        group A                some college  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...

# %%
#Para prganizar los valores por texto se usa la funcion lampda, con ella convertimos los valores en mminuscula y luego ordenamos
df_estudiante.sort_values('race/ethnicity', ascending=True,
                          key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 305    male        group A                some college      standard
# 129  female        group A           bachelor's degree      standard
# 467    male        group A                 high school  free/reduced
# 511    male        group A            some high school      standard
# 378  female        group A            some high school      standard
# ..      ...            ...                         ...           ...
# 186    male        group E                 high school      standard
# 968  female        group E          associate's degree      standard
# 269  female        group E                some college  free/reduced
# 926    male        group E          associate's degree  free/reduced
# 881  female        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  Total  \
# ...
