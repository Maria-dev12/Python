# %%
# importar pandas
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Crear un DataFrame

# %%
# leer el archivo csv "bestsellers with categories" (data sobre los 50 libros más vendidos de Amazon de 2009 a 2019.)
df_betsellers=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bestsellers+with+categories - bestsellers+with+categories.csv')

# %%
# acceder al atributo shape
df_betsellers.shape
# Out:
# (550, 7)

# %%
# encontrar el tipo de data de cada columna
type(df_betsellers)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Mostrar un DataFrame

# %%
# mostrar primeras 5 filas de un dataframe
df_betsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# encontrar valores estadisticos de un dataframe (mean, std, min, max)
df_betsellers.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# # Agregar una nueva Columna

# %%
# Tu tarea es crear una columna llamada 'Critic Rating' que deberia tener numeros random enteros entre 1 y 4
# 1.importar numpy y crear 550 numeros random enteros entre 1 y 4
aleatorio= np.random.randint(1,4,size=550)
# 2.agregar nueva columna 'Critic Rating' al dataframe usando los numeros random creados
df_betsellers['Critic Rating']=aleatorio
# Obs: Los numeros aleatorios en la columna 'Critic Rating' seran diferentes entre tu solucion y la mia, pero vamos a concetrarnos en el codigo en esta seccion.

# %%
# mostrar 5 primeras filas
df_betsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating
# 0              1
# 1              3
# 2              2
# 3              3
# 4              3

# %% [markdown]
# # Atributos, Metodos y Funciones Basicas

# %%
# acceder al atributo "columns"
df_betsellers.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'Critic Rating'],
#       dtype='object')

# %% [markdown]
# # Seleccionar 2 o Mas Columnas de un Dataframe

# %%
# mover la columna 'Critic Rating' entre las columnas "User Rating" y "Reviews" Luego actualizar el dataframe
df_betsellers.drop(columns=['Critic Rating'])
# Tip: Copiar y pegar los nombres de columna obtenidos con el atributo "columns" y reordenar los elementos usando [[]]
df_betsellers=df_betsellers.drop(columns=['Critic Rating'])
df_betsellers.insert(3,'Critic Rating',aleatorio)

# %%
# mostrar 5 primeras filas
df_betsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Critic Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7              1    17350      8  2016
# 1              Stephen King          4.6              3     2052     22  2011
# 2        Jordan B. Peterson          4.7              2    18979     15  2018
# 3             George Orwell          4.7              3    21424      6  2017
# 4  National Geographic Kids          4.8              3     7665     12  2019
#
#          Genre
# 0  Non Fiction
# 1      Fiction
# 2  Non Fiction
# 3      Fiction
# 4  Non Fiction

# %% [markdown]
# # Operaciones en Dataframes

# %%
# crear una columna llamada "Average Rating" usando la sigueinte formula: Average Rating = (User Rating + Critic Rating)/2
df_betsellers['Average Rating'] = (df_betsellers['User Rating'] + df_betsellers['Critic Rating'])/2
df_betsellers
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic Rating  Reviews  Price  \
# 0                    JJ Smith          4.7              1    17350      8
# 1                Stephen King          4.6              3     2052     22
# 2          Jordan B. Peterson          4.7              2    18979     15
# 3               George Orwell          4.7              3    21424      6
# 4    National Geographic Kids          4.8              3     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9              1     9413      8
# 546               Jen Sincero          4.7              2    14331      8
# 547               Jen Sincero          4.7              1    14331      8
# 548               Jen Sincero          4.7              3    14331      8
# 549               Jen Sincero          4.7              2    14331      8
#
#      Year        Genre  Average Rating
# 0    2016  Non Fiction            2.85
# 1    2011      Fiction            3.80
# 2    2018  Non Fiction            3.35
# 3    2017      Fiction            3.85
# 4    2019  Non Fiction            3.90
# ..    ...          ...             ...
# 545  2019      Fiction            2.95
# 546  2016  Non Fiction            3.35
# 547  2017  Non Fiction            2.85
# 548  2018  Non Fiction            3.85
# 549  2019  Non Fiction            3.35
#
# [550 rows x 9 columns]

# %%
# usar la funcion "round" para redondear los valores del dataframe a 1 decimal y actualizar el dataframe
df_betsellers.round(1)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic Rating  Reviews  Price  \
# 0                    JJ Smith          4.7              1    17350      8
# 1                Stephen King          4.6              3     2052     22
# 2          Jordan B. Peterson          4.7              2    18979     15
# 3               George Orwell          4.7              3    21424      6
# 4    National Geographic Kids          4.8              3     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9              1     9413      8
# 546               Jen Sincero          4.7              2    14331      8
# 547               Jen Sincero          4.7              1    14331      8
# 548               Jen Sincero          4.7              3    14331      8
# 549               Jen Sincero          4.7              2    14331      8
#
#      Year        Genre  Average Rating
# 0    2016  Non Fiction             2.8
# 1    2011      Fiction             3.8
# 2    2018  Non Fiction             3.4
# 3    2017      Fiction             3.8
# 4    2019  Non Fiction             3.9
# ..    ...          ...             ...
# 545  2019      Fiction             3.0
# 546  2016  Non Fiction             3.4
# 547  2017  Non Fiction             2.8
# 548  2018  Non Fiction             3.8
# 549  2019  Non Fiction             3.4
#
# [550 rows x 9 columns]

# %% [markdown]
# # Contar Valores

# %%
# contar elementos en columna "Genre" por categoria y devolver la frecuencia relativa
df_betsellers['Genre'].value_counts()
frecuencia_relativa= df_betsellers['Genre'].value_counts()/ len(df_betsellers)
frecuencia_relativa
# Out:
# Genre
# Non Fiction    0.563636
# Fiction        0.436364
# Name: count, dtype: float64

# %% [markdown]
# # Renombrar Columnas

# %%
# renombrar columnas "User Rating," "Critic Rating" y "Average Rating" a "UR," "CR" y "AR" Luego actualizar el dataframe con el parametro "inplace"
df_betsellers.rename(columns={'User Rating':'UR',
                               'Critic Rating':'CR',
                               'Average Rating':'AR'}, inplace=True)

# %%
# mostrar 5 primeras filas
df_betsellers.head(5)
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Critic Rating  Reviews  Price  Year  \
# 0                  JJ Smith          4.7              1    17350      8  2016
# 1              Stephen King          4.6              3     2052     22  2011
# 2        Jordan B. Peterson          4.7              2    18979     15  2018
# 3             George Orwell          4.7              3    21424      6  2017
# 4  National Geographic Kids          4.8              3     7665     12  2019
#
#          Genre  Average Rating
# 0  Non Fiction            2.85
# 1      Fiction            3.80
# 2  Non Fiction            3.35
# 3      Fiction            3.85
# 4  Non Fiction            3.90

# %%
# seleccionar solo columnas "Name", "Author", "UR", "CR", "AR" y "Year" y actualizar el dataframe
nuevo_df=df_betsellers.loc[:,['Name','Author','UR','CR','AR','Year']]
nuevo_df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  CR    AR  Year
# 0                    JJ Smith  4.7   1  2.85  2016
# 1                Stephen King  4.6   3  3.80  2011
# 2          Jordan B. Peterson  4.7   2  3.35  2018
# 3               George Orwell  4.7   3  3.85  2017
# 4    National Geographic Kids  4.8   3  3.90  2019
# ..                        ...  ...  ..   ...   ...
# 545               Jeff Kinney  4.9   1  2.95  2019
# 546               Jen Sincero  4.7   2  3.35  2016
# 547               Jen Sincero  4.7   1  2.85  2017
# 548               Jen Sincero  4.7   3  3.85  2018
# 549               Jen Sincero  4.7   2  3.35  2019
#
# [550 rows x 6 columns]

# %% [markdown]
# # Ordenar el dataframe

# %%
# ordenar el dataframe en forma descendente segun las columnas "UR" y "CR"
nuevo_df= nuevo_df.sort_values(by=['UR','CR'], ascending=False)
nuevo_df
# Out:
#                                                   Name           Author   UR  \
# 41            Brown Bear, Brown Bear, What Do You See?  Bill Martin Jr.  4.9
# 83   Dog Man: Brawl of the Wild: From the Creator o...       Dav Pilkey  4.9
# 87   Dog Man: Lord of the Fleas: From the Creator o...       Dav Pilkey  4.9
# 174                       Humans of New York : Stories  Brandon Stanton  4.9
# 189  Jesus Calling: Enjoying Peace in His Presence ...      Sarah Young  4.9
# ..                                                 ...              ...  ...
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...      Donna Tartt  3.9
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James  3.8
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James  3.8
# 132                         Go Set a Watchman: A Novel       Harper Lee  3.6
# 353                                 The Casual Vacancy     J.K. Rowling  3.3
#
#      CR    AR  Year
# 41    3  3.95  2019
# 83    3  3.95  2018
# 87    3  3.95  2018
# 174   3  3.95  2015
# 189   3  3.95  2013
# ..   ..   ...   ...
# 392   2  2.95  2013
# 107   3  3.40  2013
# 106   2  2.90  2012
# 132   3  3.30  2015
# 353   3  3.15  2012
#
# [550 rows x 6 columns]
